# %%
# !export PATH=/Library/TeX/texbin:$PATH

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
import glob

# %%
parent_path = '/Users/alexellard/Downloads/Hanoi_CMH/Scenario*'

# %%
demands_path = glob.glob(parent_path+'/Demands/*.csv')
flows_path = parent_path+'/Scenario*/Flows/*.csv'
leaks_path = parent_path+'/Scenario*/Leaks/*.csv'
pressures_path = parent_path+'/Scenario*/Pressures/*.csv'

# %%
no_scenarios = glob.glob(parent_path)

# %%
len(no_scenarios)
# Out:
# 180

# %%
len(demands_path)
# Out:
# 5553

# %%
total_df = []
for scenario in demands_path:
    node_csvs = glob.glob(demands_path+'/Demands/*.csv')
    for csv in node_csvs:
        demand = pd.read_csv(csv)
        total_df.append(demand)
demands_df = pd.concat(total_df)

# %%
S250_path = '/Users/alexellard/Downloads/Hanoi_CMH/Scenario-251'

# %%
timestamps = S250_path+'/Timestamps.csv'
pd.read_csv(timestamps)
# Out:
#        Index            Timestamp
# 0          1  2017-01-01 00:00:00
# 1          2  2017-01-01 00:30:00
# 2          3  2017-01-01 01:00:00
# 3          4  2017-01-01 01:30:00
# 4          5  2017-01-01 02:00:00
# ...      ...                  ...
# 17515  17516  2017-12-31 21:30:00
# 17516  17517  2017-12-31 22:00:00
# 17517  17518  2017-12-31 22:30:00
# 17518  17519  2017-12-31 23:00:00
# 17519  17520  2017-12-31 23:30:00
#
# [17520 rows x 2 columns]

# %%
demands_df = []
flows_df = []
leaks_df = []
pressures_df = []
for files in S250_path:
    timestamps = (S250_path+'/Timestamps.csv')
    demands_path = glob.glob(S250_path+'/Demands/*.csv')
    flows_path = glob.glob(S250_path+'/Flows/*.csv')
    leaks_path = glob.glob(S250_path+'/Leaks/*.csv')
    pressures_path = glob.glob(S250_path+'/Pressures/*.csv')
timestamps_df = pd.read_csv(timestamps)

#Read demands
for files in demands_path:
    df = pd.read_csv(files)
    demands_df.append(df)
for i, df in enumerate(demands_df):
    demands_df[i] = pd.merge(df, timestamps_df, on='Index')
    demands_df[i].set_index('Timestamp', inplace=True)

#Read flows
for files in flows_path:
    df = pd.read_csv(files)
    flows_df.append(df)
for i, df in enumerate(flows_df):
    flows_df[i] = pd.merge(df, timestamps_df, on='Index')
    flows_df[i].set_index('Timestamp', inplace=True)
    
#Read Leaks
for files in leaks_path:
    df = pd.read_csv(files)
    leaks_df.append(df)
#for i, df in enumerate(leaks_df):
#    demands_df[i] = pd.merge(df, timestamps_df, on='Index')
#    demands_df[i].set_index('Timestamp', inplace=True)
    
for files in pressures_path:
    df = pd.read_csv(files)
    pressures_df.append(df)
for i, df in enumerate(pressures_df):
    pressures_df[i] = pd.merge(df, timestamps_df, on='Index')
    pressures_df[i].set_index('Timestamp', inplace=True)

# %%
leaks_df[0]
# Out:
#      Description              Value
# 0      Leak Node                 15
# 1      Leak Area    0.0134285870752
# 2  Leak Diameter     0.130758642299
# 3      Leak Type             abrupt
# 4     Leak Start               6018
# 5       Leak End              16627
# 6      Peak Time               6018

# %%
# Create a Matplotlib figure object and an Axes object
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Demand over Time')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Demand')

# Plot the value column against the index (which is now the timestamp column)
ax.plot(test_df.index, test_df['Value'])

# Add gridlines
ax.grid(True)

# Show the plot
plt.show()

# %%
# Create a Matplotlib figure object and an Axes object
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Demand over Time')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Demand')

# Plot monthly demand
ax.plot(test_df.index[:4380], test_df['Value'][:4380])
ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
ax.grid(True)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-44d8cc84af7a> in <module>
#      14
#      15 # Show the plot
# ---> 16 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %%
# Create a Matplotlib figure object and an Axes object
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Demand over Time')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Demand')

# Plot monthly demand
ax.plot(test_df.index[:4380], test_df['Value'][:4380])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
# Create a Matplotlib figure object and an Axes object
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Demand over Time')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Demand')

# Plot monthly demand
ax.plot(test_df.index[:1460], test_df['Value'][:1460])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
demands_df[0]
# Out:
#                      Index  Value
# Timestamp
# 2017-01-01 00:00:00      1  129.6
# 2017-01-01 00:30:00      2  118.8
# 2017-01-01 01:00:00      3  108.0
# 2017-01-01 01:30:00      4  104.4
# 2017-01-01 02:00:00      5   97.2
# ...                    ...    ...
# 2017-12-31 21:30:00  17516  205.2
# 2017-12-31 22:00:00  17517  198.0
# 2017-12-31 22:30:00  17518  190.8
# 2017-12-31 23:00:00  17519  165.6
# 2017-12-31 23:30:00  17520  154.8
#
# [17520 rows x 2 columns]

# %%
# Create a Matplotlib figure object and an Axes object
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_title('Weekly Demand Pattern')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Demand')

# Plot monthly demand
ax.plot(test_df.index[:337], test_df['Value'][:337])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)
plt.savefig('/Users/alexellard/Downloads/WeeklyDemand.png')
# Show the plot
plt.show()

# %%
# Create a Matplotlib figure object and an Axes object
test_df = demands_df[0]
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_title('Daily Demand Pattern')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Demand')

# Plot monthly demand
ax.plot(test_df.index[:48], test_df['Value'][:48])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)
plt.savefig('/Users/alexellard/Downloads/DailyDemand.png')
# Show the plot
plt.show()

# %%
# Create a Matplotlib figure object and an Axes object
test_df = pressures_df[0]
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_title('Daily Pressure Pattern')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Pressure')

# Plot monthly demand
ax.plot(test_df.index[:48], test_df['Value'][:48])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)
plt.savefig('/Users/alexellard/Downloads/DailyPressure.png')

# Show the plot
plt.show()

# %%
# Create a Matplotlib figure object and an Axes object
test_df = flows_df[0]
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_title('Daily Flows Pattern')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Flow')

# Plot monthly demand
ax.plot(test_df.index[:48], test_df['Value'][:48])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)
plt.savefig('/Users/alexellard/Downloads/DailyFlow.png')

# Show the plot
plt.show()

# %%
#Plot a month of pressures for first node
test_df = pressures_df[0]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Pressure over Month')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Pressure')

# Plot monthly demand
ax.plot(test_df.index[:1460], test_df['Value'][:1460])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
#Plot a week of pressures for first node
test_df = pressures_df[0]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Pressure over Week')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Pressure')

# Plot monthly demand
ax.plot(test_df.index[:337], test_df['Value'][:337])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
#Plot a day of pressures for first node
test_df = pressures_df[0]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Pressure over Day')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Pressure')

# Plot monthly demand
ax.plot(test_df.index[:48], test_df['Value'][:48])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
#Plot a month of flows for first node
test_df = flows_df[0]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Flows over Month')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Flow')

# Plot monthly demand
ax.plot(test_df.index[:1460], test_df['Value'][:1460])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
#Plot a week of flows for first node
test_df = flows_df[0]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Flows over Week')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Flow')

# Plot monthly demand
ax.plot(test_df.index[:337], test_df['Value'][:337])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
#Plot a day of flows for first node
test_df = flows_df[0]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Flows over Day')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Flow')

# Plot monthly demand
ax.plot(test_df.index[:48], test_df['Value'][:48])
#ax.plot(test_df.index[4381:8761], test_df['Value'][4381:8761])
#ax.plot(test_df.index[8762:13141], test_df['Value'][8762:13141])
#ax.plot(test_df.index[13142:], test_df['Value'][13142:])
# Add gridlines
#ax.grid(True)

# Show the plot
plt.show()

# %%
conda install xelatex
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - xelatex
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.
