# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from numpy import concatenate
from math import sqrt
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/alexellard/Downloads/scenarios_data.csv', header=0, index_col=0)
df
# Out:
#                      reservoir_demand  node_1_demand  node_2_demand  \
# Timestamp
# 2017-01-01 00:00:00           -3348.0          154.8          169.2
# 2017-01-01 00:30:00           -2959.2          136.8          147.6
# 2017-01-01 01:00:00           -2692.8          129.6          126.0
# 2017-01-01 01:30:00           -2379.6          104.4          100.8
# 2017-01-01 02:00:00           -2228.4          104.4          104.4
# ...                               ...            ...            ...
# 2017-12-31 21:30:00           -5306.4          205.2          208.8
# 2017-12-31 22:00:00           -4910.4          208.8          183.6
# 2017-12-31 22:30:00           -4683.6          187.2          183.6
# 2017-12-31 23:00:00           -4262.4          180.0          165.6
# 2017-12-31 23:30:00           -3808.8          176.4          169.2
#
#                      node_3_demand  node_4_demand  node_5_demand  \
# Timestamp
# 2017-01-01 00:00:00           18.0          118.8          169.2
# 2017-01-01 00:30:00           18.0          108.0          144.0
# 2017-01-01 01:00:00           14.4          104.4          133.2
# 2017-01-01 01:30:00           10.8           86.4          122.4
# 2017-01-01 02:00:00           10.8           79.2          122.4
# ...                            ...            ...            ...
# 2017-12-31 21:30:00           39.6          183.6          284.4
# 2017-12-31 22:00:00           39.6          154.8          252.0
# 2017-12-31 22:30:00           36.0          147.6          230.4
# 2017-12-31 23:00:00           32.4          136.8          223.2
# 2017-12-31 23:30:00           25.2          122.4          201.6
#
#                      node_6_demand  node_7_demand  node_8_demand  \
# Timestamp
# 2017-01-01 00:00:00          234.0           86.4           82.8
# 2017-01-01 00:30:00          237.6           79.2           75.6
# 2017-01-01 01:00:00          205.2           72.0           72.0
# 2017-01-01 01:30:00          180.0           68.4           57.6
# 2017-01-01 02:00:00          183.6           68.4           54.0
# ...                            ...            ...            ...
# 2017-12-31 21:30:00          316.8          176.4          133.2
# 2017-12-31 22:00:00          295.2          165.6          133.2
# 2017-12-31 22:30:00          320.4          147.6          118.8
# 2017-12-31 23:00:00          241.2          147.6          115.2
# 2017-12-31 23:30:00          241.2          122.4          100.8
#
#                      node_9_demand  ...  link_23_flow  link_24_flow  \
# Timestamp                           ...
# 2017-01-01 00:00:00          104.4  ...         439.2        -205.2
# 2017-01-01 00:30:00           90.0  ...         392.4        -187.2
# 2017-01-01 01:00:00           90.0  ...         349.2        -176.4
# 2017-01-01 01:30:00           82.8  ...         316.8        -158.4
# 2017-01-01 02:00:00           75.6  ...         277.2        -144.0
# ...                            ...  ...           ...           ...
# 2017-12-31 21:30:00          129.6  ...         604.8        -259.2
# 2017-12-31 22:00:00          133.2  ...         565.2        -241.2
# 2017-12-31 22:30:00          126.0  ...         529.2        -226.8
# 2017-12-31 23:00:00          111.6  ...         496.8        -208.8
# 2017-12-31 23:30:00           93.6  ...         421.2        -180.0
#
#                      link_25_flow  link_26_flow  link_27_flow  link_28_flow  \
# Timestamp
# 2017-01-01 00:00:00         -75.6         -18.0         118.8          68.4
# 2017-01-01 00:30:00         -72.0         -21.6         108.0          61.2
# 2017-01-01 01:00:00         -64.8         -18.0          93.6          50.4
# 2017-01-01 01:30:00         -54.0         -10.8          79.2          46.8
# 2017-01-01 02:00:00         -57.6         -18.0          72.0          39.6
# ...                           ...           ...           ...           ...
# 2017-12-31 21:30:00          32.4         115.2         169.2         100.8
# 2017-12-31 22:00:00          21.6         100.8         154.8          86.4
# 2017-12-31 22:30:00          21.6         100.8         147.6          86.4
# 2017-12-31 23:00:00          21.6          93.6         133.2          79.2
# 2017-12-31 23:30:00          28.8          86.4         118.8          68.4
#
#                      link_29_flow  link_30_flow  link_31_flow  link_32_flow
# Timestamp
# 2017-01-01 00:00:00           7.2         -54.0          75.6         212.4
# 2017-01-01 00:30:00           3.6         -54.0          72.0         183.6
# 2017-01-01 01:00:00           3.6         -39.6          54.0         151.2
# 2017-01-01 01:30:00           7.2         -32.4          50.4         140.4
# 2017-01-01 02:00:00           7.2         -32.4          43.2         118.8
# ...                           ...           ...           ...           ...
# 2017-12-31 21:30:00          10.8        -100.8         122.4         309.6
# 2017-12-31 22:00:00          18.0         -75.6         100.8         288.0
# 2017-12-31 22:30:00          14.4         -86.4         108.0         266.4
# 2017-12-31 23:00:00          14.4         -75.6          97.2         255.6
# 2017-12-31 23:30:00          10.8         -68.4          86.4         216.0
#
# [87600 rows x 96 columns]

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in, n_out, vars_to_predict=None):
    n_vars = data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i-1))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(n_out):
        cols.append(df[vars_to_predict].shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in vars_to_predict]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in vars_to_predict]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    return agg

values = df.values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

# node 1 indexes
target_variable_demand_node1 = [1]
target_variable_pressures_node1 = [33]
target_variable_flows_node1 = [64]
#node 16 indexes
target_variable_demand_node16 = [16]
target_variable_pressures_node16 = [48]
target_variable_flows_node16 = [79]
#node 29 indexes
target_variable_demand_node29 = [29]
target_variable_pressures_node29 = [61]
target_variable_flows_node29 = [92]


reframed_demand_node1 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_demand_node1)
reframed_pressures_node1 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_pressures_node1)
reframed_flows_node1 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_flows_node1)

reframed_demand_node16 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_demand_node16)
reframed_pressures_node16 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_pressures_node16)
reframed_flows_node16 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_flows_node16)

reframed_demand_node29 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_demand_node29)
reframed_pressures_node29 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_pressures_node29)
reframed_flows_node29 = series_to_supervised(values, 1, 1, vars_to_predict=target_variable_flows_node29)

reframed_demand_node1 = reframed_demand_node1.drop(reframed_demand_node1.columns[1], axis=1)
reframed_pressures_node1 = reframed_pressures_node1.drop(reframed_pressures_node1.columns[33], axis=1)
reframed_flows_node1 = reframed_flows_node1.drop(reframed_flows_node1.columns[64], axis=1)

reframed_demand_node16 = reframed_demand_node16.drop(reframed_demand_node16.columns[16], axis=1)
reframed_pressures_node16 = reframed_pressures_node16.drop(reframed_pressures_node16.columns[48], axis=1)
reframed_flows_node16 = reframed_flows_node16.drop(reframed_flows_node16.columns[79], axis=1)

reframed_demand_node29 = reframed_demand_node29.drop(reframed_demand_node29.columns[29], axis=1)
reframed_pressures_node29 = reframed_pressures_node29.drop(reframed_pressures_node29.columns[61], axis=1)
reframed_flows_node29 = reframed_flows_node29.drop(reframed_flows_node29.columns[92], axis=1)

# %%
demands = [reframed_demand_node1, reframed_demand_node16, reframed_demand_node29]
pressures = [reframed_pressures_node1, reframed_pressures_node16, reframed_pressures_node29]
flows = [reframed_flows_node1, reframed_flows_node16, reframed_flows_node29]

parameters = [demands, pressures, flows]

# %%
MAE_scaled = []
RMSE_scaled = []
R2_scaled = []
MAE = []
RMSE = []
R2 = []
sensors_covered = []

for run in range(1,12):
    for parameter in parameters:
        for node in parameter:
            #select random columns to drop
            columns_to_drop = random.sample(list(node.columns), 8)
            # Drop the selected columns from the dataframe
            if node.columns[-1] in columns_to_drop:
                columns_to_drop.remove(node.columns[-1])
            node.drop(columns_to_drop, axis=1, inplace=True)
            print('Node shape: ', node.shape)

            # split into train and test sets
            values = node.values
            scaled = scaler.fit_transform(values)
            train, test = train_test_split(scaled, test_size=0.2, random_state=0)

            # split into input and outputs
            train_X, train_y = train[:, :-1], train[:, -1]
            test_X, test_y = test[:, :-1], test[:, -1]

            # define the model
            model = RandomForestRegressor(n_estimators=20, random_state=0)

            # fit the model on the training data
            model.fit(train_X, train_y)

            # make predictions on the test data
            y_pred = model.predict(test_X)

            # calculate the mean squared error
            mae = mean_absolute_error(test_y, y_pred)
            MAE_scaled.append(mae)
            print(f'Run {run} Scaled Mean Absolute Error:', mae)
            rmse = sqrt(mean_squared_error(test_y, y_pred))
            RMSE_scaled.append(rmse)
            print(f'Run {run} Scaled RMSE: %.3f' % rmse)
            r2 = r2_score(test_y, y_pred)
            print(f'Run {run} Scaled R^2: %.3f' % r2)
            R2_scaled.append(r2)

            percentage_list = round(node.shape[1] / 96 * 100)
            sensors_covered.append(percentage_list)
            
            test_y = test_y.reshape((len(test_y), 1))
            inv_test_y = concatenate((test_y, test_X[:, -node.shape[1]:]), axis=1)
            test_y_inverse = scaler.inverse_transform(inv_test_y)
            test_y_inverse = test_y_inverse[:,0]

            y_pred = y_pred.reshape((len(y_pred), 1))
            inv_y_pred = concatenate((y_pred, test_X[:, -node.shape[1]:]), axis=1)
            y_pred_inverse = scaler.inverse_transform(inv_y_pred)
            y_pred_inverse = y_pred_inverse[:,0]

            # evaluate scaled errors
            mae_inverse = mean_absolute_error(test_y_inverse, y_pred_inverse)
            MAE.append(mae_inverse)
            print('Mean Absolute Error:', mae_inverse)
            rmse_inverse = sqrt(mean_squared_error(test_y_inverse, y_pred_inverse))
            RMSE.append(rmse_inverse)
            print('RMSE: %.3f' % rmse_inverse)
            r2_inverse = r2_score(test_y_inverse, y_pred_inverse)
            R2.append(r2_inverse)
            print('R^2: %.3f' % r2_inverse)
# Out:
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.01722573081460956
# Run 1 Scaled RMSE: 0.023
# Run 1 Scaled R^2: 0.980
# Mean Absolute Error: 146.96993918513908
# RMSE: 195.677
# R^2: 0.980
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.004002839974021394
# Run 1 Scaled RMSE: 0.006
# Run 1 Scaled R^2: 0.999
# Mean Absolute Error: 34.152242698960855
# RMSE: 48.962
# R^2: 0.999
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.0069505792683560285
# Run 1 Scaled RMSE: 0.010
# Run 1 Scaled R^2: 0.996
# Mean Absolute Error: 59.302357447289715
# RMSE: 83.665
# R^2: 0.996
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.00022340524142190935
# Run 1 Scaled RMSE: 0.001
# Run 1 Scaled R^2: 1.000
# Mean Absolute Error: 1.906106538460969
# RMSE: 5.024
# R^2: 1.000
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.00046693449287109735
# Run 1 Scaled RMSE: 0.001
# Run 1 Scaled R^2: 1.000
# Mean Absolute Error: 3.9838855331543144
# RMSE: 7.377
# R^2: 1.000
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.00016568023320202423
# Run 1 Scaled RMSE: 0.000
# Run 1 Scaled R^2: 1.000
# Mean Absolute Error: 0.08648529785965564
# RMSE: 0.177
# R^2: 1.000
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 5.0309610863527006e-06
# Run 1 Scaled RMSE: 0.000
# Run 1 Scaled R^2: 1.000
# Mean Absolute Error: 0.043090544509706265
# RMSE: 0.916
# R^2: 1.000
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.0028844292196508964
# Run 1 Scaled RMSE: 0.004
# Run 1 Scaled R^2: 1.000
# Mean Absolute Error: 24.60995204673842
# RMSE: 34.056
# R^2: 1.000
# Node shape:  (87600, 88)
# Run 1 Scaled Mean Absolute Error: 0.009417523080589395
# Run 1 Scaled RMSE: 0.013
# Run 1 Scaled R^2: 0.994
# Mean Absolute Error: 80.35031793517877
# RMSE: 109.541
# R^2: 0.994
# Node shape:  (87600, 81)
# Run 2 Scaled Mean Absolute Error: 0.017128738341853023
# Run 2 Scaled RMSE: 0.023
# Run 2 Scaled R^2: 0.981
# Mean Absolute Error: 146.14240005360884
# RMSE: 194.690
# R^2: 0.981
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 0.007257467462728012
# Run 2 Scaled RMSE: 0.010
# Run 2 Scaled R^2: 0.997
# Mean Absolute Error: 61.92071628624536
# RMSE: 83.356
# R^2: 0.997
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 0.007146906721486485
# Run 2 Scaled RMSE: 0.010
# Run 2 Scaled R^2: 0.996
# Mean Absolute Error: 60.977423107721386
# RMSE: 86.469
# R^2: 0.996
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 0.00022210098292729227
# Run 2 Scaled RMSE: 0.001
# Run 2 Scaled R^2: 1.000
# Mean Absolute Error: 1.8949791046976798
# RMSE: 5.636
# R^2: 1.000
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 0.0004595742170533087
# Run 2 Scaled RMSE: 0.001
# Run 2 Scaled R^2: 1.000
# Mean Absolute Error: 3.9210880558797694
# RMSE: 7.298
# R^2: 1.000
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 0.00022034872646473305
# Run 2 Scaled RMSE: 0.000
# Run 2 Scaled R^2: 1.000
# Mean Absolute Error: 0.11502243251240714
# RMSE: 0.229
# R^2: 1.000
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 4.459071955452299e-06
# Run 2 Scaled RMSE: 0.000
# Run 2 Scaled R^2: 1.000
# Mean Absolute Error: 0.03821110402128059
# RMSE: 0.714
# R^2: 1.000
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 0.006797977436725135
# Run 2 Scaled RMSE: 0.009
# Run 2 Scaled R^2: 0.998
# Mean Absolute Error: 58.00034442821993
# RMSE: 79.087
# R^2: 0.998
# Node shape:  (87600, 80)
# Run 2 Scaled Mean Absolute Error: 0.009407748538282057
# Run 2 Scaled RMSE: 0.013
# Run 2 Scaled R^2: 0.994
# Mean Absolute Error: 80.26692211929394
# RMSE: 109.569
# R^2: 0.994
# Node shape:  (87600, 73)
# Run 3 Scaled Mean Absolute Error: 0.0166404885002178
# Run 3 Scaled RMSE: 0.022
# Run 3 Scaled R^2: 0.981
# Mean Absolute Error: 141.9766518007884
# RMSE: 190.123
# R^2: 0.981
# Node shape:  (87600, 73)
# Run 3 Scaled Mean Absolute Error: 0.007248976438999448
# Run 3 Scaled RMSE: 0.010
# Run 3 Scaled R^2: 0.997
# Mean Absolute Error: 61.848270814131695
# RMSE: 83.190
# R^2: 0.997
# Node shape:  (87600, 72)
# Run 3 Scaled Mean Absolute Error: 0.007288370559578889
# Run 3 Scaled RMSE: 0.010
# Run 3 Scaled R^2: 0.996
# Mean Absolute Error: 62.18439372133296
# RMSE: 89.042
# R^2: 0.996
# Node shape:  (87600, 72)
# Run 3 Scaled Mean Absolute Error: 0.0002247545272792279
# Run 3 Scaled RMSE: 0.001
# Run 3 Scaled R^2: 1.000
# Mean Absolute Error: 1.917617652589725
# RMSE: 4.753
# R^2: 1.000
# Node shape:  (87600, 72)
# Run 3 Scaled Mean Absolute Error: 0.000497249557751499
# Run 3 Scaled RMSE: 0.001
# Run 3 Scaled R^2: 1.000
# Mean Absolute Error: 4.242532672000663
# RMSE: 7.679
# R^2: 1.000
# Node shape:  (87600, 72)
# Run 3 Scaled Mean Absolute Error: 0.00023104443363675247
# Run 3 Scaled RMSE: 0.000
# Run 3 Scaled R^2: 1.000
# Mean Absolute Error: 0.12060554103950417
# RMSE: 0.236
# R^2: 1.000
# Node shape:  (87600, 72)
# Run 3 Scaled Mean Absolute Error: 4.570949992768808e-06
# Run 3 Scaled RMSE: 0.000
# Run 3 Scaled R^2: 1.000
# Mean Absolute Error: 0.03916574044537073
# RMSE: 0.928
# R^2: 1.000
# Node shape:  (87600, 72)
# Run 3 Scaled Mean Absolute Error: 0.007393960503342489
# Run 3 Scaled RMSE: 0.010
# Run 3 Scaled R^2: 0.997
# Mean Absolute Error: 63.08527238787282
# RMSE: 85.383
# R^2: 0.997
# Node shape:  (87600, 72)
# Run 3 Scaled Mean Absolute Error: 0.009400899168444143
# Run 3 Scaled RMSE: 0.013
# Run 3 Scaled R^2: 0.994
# Mean Absolute Error: 80.20848324736406
# RMSE: 109.180
# R^2: 0.994
# Node shape:  (87600, 66)
# Run 4 Scaled Mean Absolute Error: 0.017426467030202824
# Run 4 Scaled RMSE: 0.023
# Run 4 Scaled R^2: 0.980
# Mean Absolute Error: 148.6826221096007
# RMSE: 197.515
# R^2: 0.980
# Node shape:  (87600, 66)
# Run 4 Scaled Mean Absolute Error: 0.007149090791614429
# Run 4 Scaled RMSE: 0.010
# Run 4 Scaled R^2: 0.997
# Mean Absolute Error: 60.996046753283075
# RMSE: 82.195
# R^2: 0.997
# Node shape:  (87600, 64)
# Run 4 Scaled Mean Absolute Error: 0.007282859608913733
# Run 4 Scaled RMSE: 0.010
# Run 4 Scaled R^2: 0.996
# Mean Absolute Error: 62.13737807750235
# RMSE: 88.992
# R^2: 0.996
# Node shape:  (87600, 64)
# Run 4 Scaled Mean Absolute Error: 0.00021745977880747533
# Run 4 Scaled RMSE: 0.001
# Run 4 Scaled R^2: 1.000
# Mean Absolute Error: 1.8553797983075857
# RMSE: 5.132
# R^2: 1.000
# Node shape:  (87600, 64)
# Run 4 Scaled Mean Absolute Error: 0.0004979750350730061
# Run 4 Scaled RMSE: 0.001
# Run 4 Scaled R^2: 1.000
# Mean Absolute Error: 4.2487227183690734
# RMSE: 7.701
# R^2: 1.000
# Node shape:  (87600, 64)
# Run 4 Scaled Mean Absolute Error: 0.0002276281264002463
# Run 4 Scaled RMSE: 0.000
# Run 4 Scaled R^2: 1.000
# Mean Absolute Error: 0.118822082730479
# RMSE: 0.223
# R^2: 1.000
# Node shape:  (87600, 64)
# Run 4 Scaled Mean Absolute Error: 4.12304485939684e-06
# Run 4 Scaled RMSE: 0.000
# Run 4 Scaled R^2: 1.000
# Mean Absolute Error: 0.03534408237250724
# RMSE: 0.706
# R^2: 1.000
# Node shape:  (87600, 64)
# Run 4 Scaled Mean Absolute Error: 0.007312170314904489
# Run 4 Scaled RMSE: 0.010
# Run 4 Scaled R^2: 0.997
# Mean Absolute Error: 62.387438187577494
# RMSE: 84.585
# R^2: 0.997
# Node shape:  (87600, 65)
# Run 4 Scaled Mean Absolute Error: 0.009404109823964025
# Run 4 Scaled RMSE: 0.013
# Run 4 Scaled R^2: 0.994
# Mean Absolute Error: 80.2358765894533
# RMSE: 109.334
# R^2: 0.994
# Node shape:  (87600, 58)
# Run 5 Scaled Mean Absolute Error: 0.017744625383205544
# Run 5 Scaled RMSE: 0.024
# Run 5 Scaled R^2: 0.979
# Mean Absolute Error: 151.3971497892803
# RMSE: 201.367
# R^2: 0.979
# Node shape:  (87600, 58)
# Run 5 Scaled Mean Absolute Error: 0.007432922221099337
# Run 5 Scaled RMSE: 0.010
# Run 5 Scaled R^2: 0.997
# Mean Absolute Error: 63.41769814146625
# RMSE: 85.837
# R^2: 0.997
# Node shape:  (87600, 56)
# Run 5 Scaled Mean Absolute Error: 0.007201917728613296
# Run 5 Scaled RMSE: 0.010
# Run 5 Scaled R^2: 0.996
# Mean Absolute Error: 61.44677972922958
# RMSE: 88.036
# R^2: 0.996
# Node shape:  (87600, 56)
# Run 5 Scaled Mean Absolute Error: 0.00020473478047270397
# Run 5 Scaled RMSE: 0.001
# Run 5 Scaled R^2: 1.000
# Mean Absolute Error: 1.746811130436288
# RMSE: 4.336
# R^2: 1.000
# Node shape:  (87600, 57)
# Run 5 Scaled Mean Absolute Error: 0.0005149451877972849
# Run 5 Scaled RMSE: 0.001
# Run 5 Scaled R^2: 1.000
# Mean Absolute Error: 4.393512803298514
# RMSE: 8.080
# R^2: 1.000
# Node shape:  (87600, 57)
# Run 5 Scaled Mean Absolute Error: 0.0002442006759991925
# Run 5 Scaled RMSE: 0.000
# Run 5 Scaled R^2: 1.000
# Mean Absolute Error: 0.11340734587321633
# RMSE: 0.203
# R^2: 1.000
# Node shape:  (87600, 56)
# Run 5 Scaled Mean Absolute Error: 3.7991198111478417e-06
# Run 5 Scaled RMSE: 0.000
# Run 5 Scaled R^2: 1.000
# Mean Absolute Error: 0.03258037870102438
# RMSE: 0.573
# R^2: 1.000
# Node shape:  (87600, 56)
# Run 5 Scaled Mean Absolute Error: 0.007240297143011605
# Run 5 Scaled RMSE: 0.010
# Run 5 Scaled R^2: 0.997
# Mean Absolute Error: 61.77421610042964
# RMSE: 83.852
# R^2: 0.997
# Node shape:  (87600, 57)
# Run 5 Scaled Mean Absolute Error: 0.011945847823097454
# Run 5 Scaled RMSE: 0.016
# Run 5 Scaled R^2: 0.992
# Mean Absolute Error: 101.92198203553477
# RMSE: 132.943
# R^2: 0.992
# Node shape:  (87600, 50)
# Run 6 Scaled Mean Absolute Error: 0.01830455691864093
# Run 6 Scaled RMSE: 0.024
# Run 6 Scaled R^2: 0.978
# Mean Absolute Error: 156.1744848444116
# RMSE: 205.855
# R^2: 0.978
# Node shape:  (87600, 50)
# Run 6 Scaled Mean Absolute Error: 0.007382401317511111
# Run 6 Scaled RMSE: 0.010
# Run 6 Scaled R^2: 0.997
# Mean Absolute Error: 62.986654441434844
# RMSE: 85.088
# R^2: 0.997
# Node shape:  (87600, 48)
# Run 6 Scaled Mean Absolute Error: 0.007186565780012814
# Run 6 Scaled RMSE: 0.010
# Run 6 Scaled R^2: 0.996
# Mean Absolute Error: 61.31579624490541
# RMSE: 88.057
# R^2: 0.996
# Node shape:  (87600, 49)
# Run 6 Scaled Mean Absolute Error: 0.00019675259176454222
# Run 6 Scaled RMSE: 0.001
# Run 6 Scaled R^2: 1.000
# Mean Absolute Error: 1.6787091477744431
# RMSE: 5.451
# R^2: 1.000
# Node shape:  (87600, 49)
# Run 6 Scaled Mean Absolute Error: 0.0005065777183395541
# Run 6 Scaled RMSE: 0.001
# Run 6 Scaled R^2: 1.000
# Mean Absolute Error: 4.3221213874792825
# RMSE: 7.950
# R^2: 1.000
# Node shape:  (87600, 49)
# Run 6 Scaled Mean Absolute Error: 0.0004786910950184956
# Run 6 Scaled RMSE: 0.001
# Run 6 Scaled R^2: 1.000
# Mean Absolute Error: 0.22230482491549
# RMSE: 0.412
# R^2: 1.000
# Node shape:  (87600, 48)
# Run 6 Scaled Mean Absolute Error: 3.984554470878278e-06
# Run 6 Scaled RMSE: 0.000
# Run 6 Scaled R^2: 1.000
# Mean Absolute Error: 0.03416295033587427
# RMSE: 0.660
# R^2: 1.000
# Node shape:  (87600, 48)
# Run 6 Scaled Mean Absolute Error: 0.007148988856062225
# Run 6 Scaled RMSE: 0.010
# Run 6 Scaled R^2: 0.997
# Mean Absolute Error: 60.995173710515964
# RMSE: 82.789
# R^2: 0.997
# Node shape:  (87600, 50)
# Run 6 Scaled Mean Absolute Error: 0.011940068755889967
# Run 6 Scaled RMSE: 0.016
# Run 6 Scaled R^2: 0.992
# Mean Absolute Error: 101.87267593317617
# RMSE: 133.152
# R^2: 0.992
# Node shape:  (87600, 42)
# Run 7 Scaled Mean Absolute Error: 0.018202584753893147
# Run 7 Scaled RMSE: 0.024
# Run 7 Scaled R^2: 0.978
# Mean Absolute Error: 155.30445735942496
# RMSE: 204.605
# R^2: 0.978
# Node shape:  (87600, 42)
# Run 7 Scaled Mean Absolute Error: 0.013228140679915271
# Run 7 Scaled RMSE: 0.018
# Run 7 Scaled R^2: 0.989
# Mean Absolute Error: 112.86249948124873
# RMSE: 155.597
# R^2: 0.989
# Node shape:  (87600, 40)
# Run 7 Scaled Mean Absolute Error: 0.007007459864705019
# Run 7 Scaled RMSE: 0.010
# Run 7 Scaled R^2: 0.996
# Mean Absolute Error: 2.119056398979999
# RMSE: 3.021
# R^2: 0.996
# Node shape:  (87600, 41)
# Run 7 Scaled Mean Absolute Error: 0.0002052691320306051
# Run 7 Scaled RMSE: 0.001
# Run 7 Scaled R^2: 1.000
# Mean Absolute Error: 0.053208534504431436
# RMSE: 0.160
# R^2: 1.000
# Node shape:  (87600, 41)
# Run 7 Scaled Mean Absolute Error: 0.0004984260598818463
# Run 7 Scaled RMSE: 0.001
# Run 7 Scaled R^2: 1.000
# Mean Absolute Error: 4.252571447741803
# RMSE: 7.826
# R^2: 1.000
# Node shape:  (87600, 42)
# Run 7 Scaled Mean Absolute Error: 0.00047586739403472075
# Run 7 Scaled RMSE: 0.001
# Run 7 Scaled R^2: 1.000
# Mean Absolute Error: 0.2209936320303902
# RMSE: 0.409
# R^2: 1.000
# Node shape:  (87600, 40)
# Run 7 Scaled Mean Absolute Error: 0.0013649162052190736
# Run 7 Scaled RMSE: 0.002
# Run 7 Scaled R^2: 1.000
# Mean Absolute Error: 0.38818220745252496
# RMSE: 0.510
# R^2: 1.000
# Node shape:  (87600, 40)
# Run 7 Scaled Mean Absolute Error: 0.008772113819406728
# Run 7 Scaled RMSE: 0.012
# Run 7 Scaled R^2: 0.996
# Mean Absolute Error: 4.579043607430667
# RMSE: 6.119
# R^2: 0.996
# Node shape:  (87600, 42)
# Run 7 Scaled Mean Absolute Error: 0.019102740092777123
# Run 7 Scaled RMSE: 0.025
# Run 7 Scaled R^2: 0.978
# Mean Absolute Error: 162.9845875107351
# RMSE: 217.094
# R^2: 0.978
# Node shape:  (87600, 34)
# Run 8 Scaled Mean Absolute Error: 0.01776391376613652
# Run 8 Scaled RMSE: 0.023
# Run 8 Scaled R^2: 0.980
# Mean Absolute Error: 151.56171741591942
# RMSE: 199.527
# R^2: 0.980
# Node shape:  (87600, 34)
# Run 8 Scaled Mean Absolute Error: 0.012466744086556306
# Run 8 Scaled RMSE: 0.017
# Run 8 Scaled R^2: 0.991
# Mean Absolute Error: 106.36626090434973
# RMSE: 146.571
# R^2: 0.991
# Node shape:  (87600, 32)
# Run 8 Scaled Mean Absolute Error: 0.01753168897003735
# Run 8 Scaled RMSE: 0.023
# Run 8 Scaled R^2: 0.980
# Mean Absolute Error: 5.301583238064114
# RMSE: 6.938
# R^2: 0.980
# Node shape:  (87600, 33)
# Run 8 Scaled Mean Absolute Error: 0.00018937491935137334
# Run 8 Scaled RMSE: 0.001
# Run 8 Scaled R^2: 1.000
# Mean Absolute Error: 0.04908889061022811
# RMSE: 0.130
# R^2: 1.000
# Node shape:  (87600, 33)
# Run 8 Scaled Mean Absolute Error: 0.0006676513943225823
# Run 8 Scaled RMSE: 0.001
# Run 8 Scaled R^2: 1.000
# Mean Absolute Error: 5.696401091377597
# RMSE: 9.427
# R^2: 1.000
# Node shape:  (87600, 34)
# Run 8 Scaled Mean Absolute Error: 0.0005486869934487016
# Run 8 Scaled RMSE: 0.001
# Run 8 Scaled R^2: 1.000
# Mean Absolute Error: 0.2548110721965778
# RMSE: 0.491
# R^2: 1.000
# Node shape:  (87600, 32)
# Run 8 Scaled Mean Absolute Error: 0.0013649236099990123
# Run 8 Scaled RMSE: 0.002
# Run 8 Scaled R^2: 1.000
# Mean Absolute Error: 0.3881842972022079
# RMSE: 0.511
# R^2: 1.000
# Node shape:  (87600, 33)
# Run 8 Scaled Mean Absolute Error: 0.01047119389590063
# Run 8 Scaled RMSE: 0.014
# Run 8 Scaled R^2: 0.994
# Mean Absolute Error: 5.465963444868623
# RMSE: 7.215
# R^2: 0.994
# Node shape:  (87600, 34)
# Run 8 Scaled Mean Absolute Error: 0.019412172218087265
# Run 8 Scaled RMSE: 0.026
# Run 8 Scaled R^2: 0.977
# Mean Absolute Error: 165.62466456418326
# RMSE: 220.551
# R^2: 0.977
# Node shape:  (87600, 26)
# Run 9 Scaled Mean Absolute Error: 0.017609784500035523
# Run 9 Scaled RMSE: 0.023
# Run 9 Scaled R^2: 0.980
# Mean Absolute Error: 4.564455861014722
# RMSE: 6.050
# R^2: 0.980
# Node shape:  (87600, 26)
# Run 9 Scaled Mean Absolute Error: 0.014233674074748539
# Run 9 Scaled RMSE: 0.019
# Run 9 Scaled R^2: 0.988
# Mean Absolute Error: 121.44170980454865
# RMSE: 163.693
# R^2: 0.988
# Node shape:  (87600, 24)
# Run 9 Scaled Mean Absolute Error: 0.01740985796359457
# Run 9 Scaled RMSE: 0.023
# Run 9 Scaled R^2: 0.980
# Mean Absolute Error: 5.2647415497354935
# RMSE: 6.863
# R^2: 0.980
# Node shape:  (87600, 25)
# Run 9 Scaled Mean Absolute Error: 0.00018792106680673708
# Run 9 Scaled RMSE: 0.001
# Run 9 Scaled R^2: 1.000
# Mean Absolute Error: 0.04871225889397216
# RMSE: 0.139
# R^2: 1.000
# Node shape:  (87600, 26)
# Run 9 Scaled Mean Absolute Error: 0.0014510114331087562
# Run 9 Scaled RMSE: 0.002
# Run 9 Scaled R^2: 1.000
# Mean Absolute Error: 0.7208621116948349
# RMSE: 1.157
# R^2: 1.000
# Node shape:  (87600, 26)
# Run 9 Scaled Mean Absolute Error: 0.0005483058510033508
# Run 9 Scaled RMSE: 0.001
# Run 9 Scaled R^2: 1.000
# Mean Absolute Error: 0.2546339555705307
# RMSE: 0.492
# R^2: 1.000
# Node shape:  (87600, 25)
# Run 9 Scaled Mean Absolute Error: 0.0014776026263628923
# Run 9 Scaled RMSE: 0.002
# Run 9 Scaled R^2: 1.000
# Mean Absolute Error: 0.42023020017015605
# RMSE: 0.583
# R^2: 1.000
# Node shape:  (87600, 25)
# Run 9 Scaled Mean Absolute Error: 0.01052127243534207
# Run 9 Scaled RMSE: 0.014
# Run 9 Scaled R^2: 0.994
# Mean Absolute Error: 5.4921043196014585
# RMSE: 7.252
# R^2: 0.994
# Node shape:  (87600, 27)
# Run 9 Scaled Mean Absolute Error: 0.021289526570809486
# Run 9 Scaled RMSE: 0.028
# Run 9 Scaled R^2: 0.973
# Mean Absolute Error: 181.6422502002949
# RMSE: 241.325
# R^2: 0.973
# Node shape:  (87600, 18)
# Run 10 Scaled Mean Absolute Error: 0.022332859450236782
# Run 10 Scaled RMSE: 0.029
# Run 10 Scaled R^2: 0.968
# Mean Absolute Error: 5.788676787710131
# RMSE: 7.612
# R^2: 0.968
# Node shape:  (87600, 19)
# Run 10 Scaled Mean Absolute Error: 0.014330705965073891
# Run 10 Scaled RMSE: 0.019
# Run 10 Scaled R^2: 0.988
# Mean Absolute Error: 3.404975752737857
# RMSE: 4.590
# R^2: 0.988
# Node shape:  (87600, 16)
# Run 10 Scaled Mean Absolute Error: 0.01765327440576892
# Run 10 Scaled RMSE: 0.023
# Run 10 Scaled R^2: 0.980
# Mean Absolute Error: 2.5420714992818727
# RMSE: 3.306
# R^2: 0.980
# Node shape:  (87600, 18)
# Run 10 Scaled Mean Absolute Error: 0.00018503678988103633
# Run 10 Scaled RMSE: 0.001
# Run 10 Scaled R^2: 1.000
# Mean Absolute Error: 0.04796500758537001
# RMSE: 0.130
# R^2: 1.000
# Node shape:  (87600, 18)
# Run 10 Scaled Mean Absolute Error: 0.0014902513266698409
# Run 10 Scaled RMSE: 0.002
# Run 10 Scaled R^2: 1.000
# Mean Absolute Error: 0.7403565948719537
# RMSE: 1.187
# R^2: 1.000
# Node shape:  (87600, 19)
# Run 10 Scaled Mean Absolute Error: 0.0009201433734126287
# Run 10 Scaled RMSE: 0.001
# Run 10 Scaled R^2: 1.000
# Mean Absolute Error: 0.42731464876758685
# RMSE: 0.666
# R^2: 1.000
# Node shape:  (87600, 18)
# Run 10 Scaled Mean Absolute Error: 0.0016209119072260513
# Run 10 Scaled RMSE: 0.002
# Run 10 Scaled R^2: 1.000
# Mean Absolute Error: 0.4609872880712607
# RMSE: 0.637
# R^2: 1.000
# Node shape:  (87600, 17)
# Run 10 Scaled Mean Absolute Error: 0.010870673525823306
# Run 10 Scaled RMSE: 0.014
# Run 10 Scaled R^2: 0.994
# Mean Absolute Error: 5.674491775907725
# RMSE: 7.462
# R^2: 0.994
# Node shape:  (87600, 19)
# Run 10 Scaled Mean Absolute Error: 0.02189883018639704
# Run 10 Scaled RMSE: 0.029
# Run 10 Scaled R^2: 0.972
# Mean Absolute Error: 186.84082955409858
# RMSE: 246.793
# R^2: 0.972
# Node shape:  (87600, 10)
# Run 11 Scaled Mean Absolute Error: 0.022535583142437827
# Run 11 Scaled RMSE: 0.030
# Run 11 Scaled R^2: 0.967
# Mean Absolute Error: 3.894148534339868
# RMSE: 5.103
# R^2: 0.967
# Node shape:  (87600, 11)
# Run 11 Scaled Mean Absolute Error: 0.021982126774555542
# Run 11 Scaled RMSE: 0.029
# Run 11 Scaled R^2: 0.974
# Mean Absolute Error: 5.222953237734333
# RMSE: 6.815
# R^2: 0.974
# Node shape:  (87600, 9)
# Run 11 Scaled Mean Absolute Error: 0.02088003166056276
# Run 11 Scaled RMSE: 0.027
# Run 11 Scaled R^2: 0.972
# Mean Absolute Error: 0.5261768417735716
# RMSE: 0.687
# R^2: 0.972
# Node shape:  (87600, 11)
# Run 11 Scaled Mean Absolute Error: 0.0011198130045851613
# Run 11 Scaled RMSE: 0.004
# Run 11 Scaled R^2: 0.999
# Mean Absolute Error: 0.2902559651603694
# RMSE: 1.092
# R^2: 0.999
# Node shape:  (87600, 10)
# Run 11 Scaled Mean Absolute Error: 0.0020597379450520426
# Run 11 Scaled RMSE: 0.003
# Run 11 Scaled R^2: 0.999
# Mean Absolute Error: 1.0232776606932683
# RMSE: 1.548
# R^2: 0.999
# Node shape:  (87600, 12)
# Run 11 Scaled Mean Absolute Error: 0.001888652946714942
# Run 11 Scaled RMSE: 0.003
# Run 11 Scaled R^2: 1.000
# Mean Absolute Error: 0.8770904837928409
# RMSE: 1.332
# R^2: 1.000
# Node shape:  (87600, 10)
# Run 11 Scaled Mean Absolute Error: 0.0023789124839331053
# Run 11 Scaled RMSE: 0.004
# Run 11 Scaled R^2: 1.000
# Mean Absolute Error: 0.6765627004911278
# RMSE: 1.036
# R^2: 1.000
# Node shape:  (87600, 9)
# Run 11 Scaled Mean Absolute Error: 0.011427387985906916
# Run 11 Scaled RMSE: 0.015
# Run 11 Scaled R^2: 0.993
# Mean Absolute Error: 5.965096772391826
# RMSE: 7.831
# R^2: 0.993
# Node shape:  (87600, 12)
# Run 11 Scaled Mean Absolute Error: 0.022494506534469653
# Run 11 Scaled RMSE: 0.030
# Run 11 Scaled R^2: 0.970
# Mean Absolute Error: 191.92314246538325
# RMSE: 253.661
# R^2: 0.970

# %%
demand_errors_mae_node1 = MAE[::9]
demand_errors_mae_node16 = MAE[1::9]
demand_errors_mae_node29 = MAE[2::9]
pressure_errors_mae_node1 = MAE[3::9]
pressure_errors_mae_node16 = MAE[4::9]
pressure_errors_mae_node29 = MAE[5::9]
flow_errors_mae_node1 = MAE[6::9]
flow_errors_mae_node16 = MAE[7::9]
flow_errors_mae_node29 = MAE[8::9]

demand_errors_rmse_node1 = RMSE[::9]
demand_errors_rmse_node16 = RMSE[1::9]
demand_errors_rmse_node29 = RMSE[2::9]
pressure_errors_rmse_node1 = RMSE[3::9]
pressure_errors_rmse_node16 = RMSE[4::9]
pressure_errors_rmse_node29 = RMSE[5::9]
flow_errors_rmse_node1 = RMSE[6::9]
flow_errors_rmse_node16 = RMSE[7::9]
flow_errors_rmse_node29 = RMSE[8::9]

demand_errors_r2_node1 = R2[::9]
demand_errors_r2_node16 = R2[1::9]
demand_errors_r2_node29 = R2[2::9]
pressure_errors_r2_node1 = R2[3::9]
pressure_errors_r2_node16 = R2[4::9]
pressure_errors_r2_node29 = R2[5::9]
flow_errors_r2_node1 = R2[6::9]
flow_errors_r2_node16 = R2[7::9]
flow_errors_r2_node29 = R2[8::9]

demand_sensors_covered_node1 = sensors_covered[::9]
demand_sensors_covered_node16 = sensors_covered[1::9]
demand_sensors_covered_node29 = sensors_covered[2::9]
pressure_sensors_covered_node1 = sensors_covered[3::9]
pressure_sensors_covered_node16 = sensors_covered[4::9]
pressure_sensors_covered_node29 = sensors_covered[5::9]
flow_sensors_covered_node1 = sensors_covered[6::9]
flow_sensors_covered_node16 = sensors_covered[7::9]
flow_sensors_covered_node29 = sensors_covered[8::9]

# %%
plt.plot(demand_sensors_covered_node1, demand_errors_mae_node1)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE Error vs. Coverage Demands Node 1")
plt.xlim([100, 0])
plt.show()

plt.plot(demand_sensors_covered_node1, demand_errors_rmse_node1)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Demands Node 1")
plt.xlim([100, 0])
plt.show()

plt.plot(demand_sensors_covered_node1, demand_errors_r2_node1)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 Error vs. Coverage Demands Node 1")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(demand_sensors_covered_node16, demand_errors_mae_node16)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Demands Node 16")
plt.xlim([100, 0])
plt.show()

plt.plot(demand_sensors_covered_node16, demand_errors_rmse_node16)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Demands Node 16")
plt.xlim([100, 0])
plt.show()

plt.plot(demand_sensors_covered_node16, demand_errors_r2_node16)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Demands Node 16")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(demand_sensors_covered_node29, demand_errors_mae_node29)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Demands Node 29")
plt.xlim([100, 0])
plt.show()

plt.plot(demand_sensors_covered_node29, demand_errors_rmse_node29)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Demands Node 29")
plt.xlim([100, 0])
plt.show()

plt.plot(demand_sensors_covered_node29, demand_errors_r2_node29)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Demands Node 29")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(pressure_sensors_covered_node1, pressure_errors_mae_node1)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Pressure Node 1")
plt.xlim([100, 0])
plt.show()

plt.plot(pressure_sensors_covered_node1, pressure_errors_rmse_node1)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Pressure Node 1")
plt.xlim([100, 0])
plt.show()

plt.plot(pressure_sensors_covered_node1, pressure_errors_r2_node1)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Pressure Node 1")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(pressure_sensors_covered_node16, pressure_errors_mae_node16)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Pressure Node 16")
plt.xlim([100, 0])
plt.show()

plt.plot(pressure_sensors_covered_node16, pressure_errors_rmse_node16)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Pressure Node 16")
plt.xlim([100, 0])
plt.show()

plt.plot(pressure_sensors_covered_node16, pressure_errors_r2_node16)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Pressure Node 16")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(pressure_sensors_covered_node29, pressure_errors_mae_node29)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Pressure Node 29")
plt.xlim([100, 0])
plt.show()

plt.plot(pressure_sensors_covered_node29, pressure_errors_rmse_node29)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Pressure Node 29")
plt.xlim([100, 0])
plt.show()

plt.plot(pressure_sensors_covered_node29, pressure_errors_r2_node29)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Pressure Node 29")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(flow_sensors_covered_node1, flow_errors_mae_node1)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Flows Node 1")
plt.xlim([100, 0])
plt.show()

plt.plot(flow_sensors_covered_node1, flow_errors_rmse_node1)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Flows Node 1")
plt.xlim([100, 0])
plt.show()

plt.plot(flow_sensors_covered_node1, flow_errors_r2_node1)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Flows Node 1")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(flow_sensors_covered_node16, flow_errors_mae_node16)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Flows Node 16")
plt.xlim([100, 0])
plt.show()

plt.plot(flow_sensors_covered_node16, flow_errors_rmse_node16)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Flows Node 16")
plt.xlim([100, 0])
plt.show()

plt.plot(flow_sensors_covered_node16, flow_errors_r2_node16)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Flows Node 16")
plt.xlim([100, 0])
plt.show()

# %%
plt.plot(flow_sensors_covered_node29, flow_errors_mae_node29)
plt.ylabel("Mean Absolute Error")
plt.xlabel("Sensor Cover %")
plt.title("MAE vs. Coverage Flows Node 29")
plt.xlim([100, 0])
plt.show()

plt.plot(flow_sensors_covered_node29, flow_errors_rmse_node29)
plt.ylabel("RMSE")
plt.xlabel("Sensor Cover %")
plt.title("RMSE vs. Coverage Flows Node 29")
plt.xlim([100, 0])
plt.show()

plt.plot(flow_sensors_covered_node29, flow_errors_r2_node29)
plt.ylabel("R2")
plt.xlabel("Sensor Cover %")
plt.title("R2 vs. Coverage Flows Node 29")
plt.xlim([100, 0])
plt.show()
